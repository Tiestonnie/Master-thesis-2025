# %%
import matplotlib.pyplot as plt

# Example data with ten trained accuracies per region
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1 = {
    '14 days': [0.6272, 0.6145, 0.6239, 0.6296, 0.6201, 0.6198, 0.6198, 0.6095, 0.6248, 0.6093],
    '21 days': [0.5947, 0.5798, 0.5858, 0.5934, 0.5827, 0.5952, 0.5911, 0.5767, 0.5865, 0.5774],
    '28 days': [0.5725, 0.5629, 0.5660, 0.5667, 0.5553, 0.5750, 0.5735, 0.5625, 0.5674, 0.5577],
    '35 days': [0.5514, 0.5529, 0.5560, 0.5507, 0.5371, 0.5549, 0.5589, 0.5474, 0.5500, 0.5457],
    '42 days': [0.5375, 0.5430, 0.5452, 0.5356, 0.5230, 0.5415, 0.5383, 0.5342, 0.5380, 0.5387],
    '49 days': [0.5278, 0.5266, 0.5365, 0.5200, 0.5163, 0.5279, 0.5241, 0.5230, 0.5202, 0.5300],
    '56 days': [0.5168, 0.5182, 0.5272, 0.5129, 0.5141, 0.5241, 0.5259, 0.5208, 0.5117, 0.5234]
}

model2 = {
    '14 days': [0.5906, 0.5942, 0.5970, 0.5913, 0.5893],
    '21 days': [0.5650, 0.5730, 0.5720, 0.5696, 0.5782],
    '28 days': [0.5544, 0.5593, 0.5507, 0.5439, 0.5595],
    '35 days': [0.5493, 0.5522, 0.5365, 0.5346, 0.5484],
    '42 days': [0.5466, 0.5380, 0.5266, 0.5206, 0.5352],
    '49 days': [0.5267, 0.5357, 0.5295, 0.5183, 0.5333],
    '56 days': [0.5239, 0.5318, 0.5192, 0.5278, 0.5342]
}

# Plotting
plt.figure(figsize=(8, 6))
for region in regions:
    # Use model1 for trained accuracies to match all regions
    plt.scatter([region] * len(model1[region]), model1[region], 
                label='Model 1' if regions[0] == region else "", color='orange', alpha=0.6, marker='s')
    plt.scatter([region] * len(model2[region]), model2[region], 
                label='Model 2' if regions[0] == region else "", color='blue', alpha=0.6, marker='d')

# Adding a reference line at 50% accuracy
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)

# Labels and title
plt.xlabel('lead time')
plt.ylabel('Accuracy')
plt.title('CESM2 Accuracy of model 1 and model 2')
plt.legend()

# Show plot
plt.show()

# %%
# Accuracy of baseline models 1 and 2

import matplotlib.pyplot as plt

# Data
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1 = {
    '14 days': [0.6272, 0.6145, 0.6239, 0.6296, 0.6201],# 0.6198, 0.6198, 0.6095, 0.6248, 0.6093],
    '21 days': [0.5947, 0.5798, 0.5858, 0.5934, 0.5827],# 0.5952, 0.5911, 0.5767, 0.5865, 0.5774],
    '28 days': [0.5725, 0.5629, 0.5660, 0.5667, 0.5553],# 0.5750, 0.5735, 0.5625, 0.5674, 0.5577],
    '35 days': [0.5514, 0.5529, 0.5560, 0.5507, 0.5371],# 0.5549, 0.5589, 0.5474, 0.5500, 0.5457],
    '42 days': [0.5375, 0.5430, 0.5452, 0.5356, 0.5230], # 0.5415, 0.5383, 0.5342, 0.5380, 0.5387],
    '49 days': [0.5278, 0.5266, 0.5365, 0.5200, 0.5163], #, 0.5279, 0.5241, 0.5230, 0.5202, 0.5300],
    '56 days': [0.5168, 0.5182, 0.5272, 0.5129, 0.5141] #, 0.5241, 0.5259, 0.5208, 0.5117, 0.5234]
}
model2 = {
    '14 days': [0.5906, 0.5942, 0.5970, 0.5913, 0.5893],
    '21 days': [0.5650, 0.5730, 0.5720, 0.5696, 0.5782],
    '28 days': [0.5544, 0.5593, 0.5507, 0.5439, 0.5595],
    '35 days': [0.5493, 0.5522, 0.5365, 0.5346, 0.5484],
    '42 days': [0.5466, 0.5380, 0.5266, 0.5206, 0.5352],
    '49 days': [0.5267, 0.5357, 0.5295, 0.5183, 0.5333],
    '56 days': [0.5239, 0.5318, 0.5192, 0.5278, 0.5342]
}

# Calculate averages
avg_model1 = {region: sum(model1[region]) / len(model1[region]) for region in regions}
avg_model2 = {region: sum(model2[region]) / len(model2[region]) for region in regions}

# Plotting
plt.figure(figsize=(10, 6))
for region in regions:
    plt.scatter([region] * len(model1[region]), model1[region], label='Model 1' if regions[0] == region else "", 
                color='orange', alpha=0.6, marker='d')
    plt.scatter([region] * len(model2[region]), model2[region], label='Model 2' if regions[0] == region else "", 
                color='blue', alpha=0.6, marker='d')
    plt.scatter(region, avg_model1[region], color='darkorange', marker='s', s=50)
    plt.scatter(region, avg_model2[region], color='darkblue', marker='s', s=50)

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.title('Accuracy of the baseline models on the CESM2 test set')
plt.legend()

# Show plot
plt.show()

# %%
# MSRE of baseline models 1 and 2

import matplotlib.pyplot as plt

# Data
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1 = {
'14 days': [0.4766, 0.4750, 0.4752, 0.4760, 0.4755],
'21 days': [0.4851, 0.4851, 0.4849, 0.4851, 0.4851],
'28 days': [0.4929, 0.4920, 0.4921, 0.4927, 0.4926],
'35 days': [0.4964, 0.4954, 0.4959, 0.4962, 0.4963],
'42 days': [0.4979, 0.4976, 0.4977, 0.4979, 0.4981],
'49 days': [0.4991, 0.4989, 0.4989, 0.4991, 0.4992],
'56 days': [0.4994, 0.4989, 0.4991, 0.4993, 0.4994]
}

model2 = {
'14 days': [0.4869, 0.4872, 0.4869, 0.4870, 0.4869],
'21 days': [0.4921, 0.4920, 0.4919, 0.4922, 0.4920],
'28 days': [0.4954, 0.4951, 0.4956, 0.4950, 0.4950],
'35 days': [0.4976, 0.4974, 0.4972, 0.4973, 0.4973],
'42 days': [0.4984, 0.4984, 0.4982, 0.4981, 0.4983],
'49 days': [0.4995, 0.4998, 0.4998, 0.4993, 0.4996],
'56 days': [0.4991, 0.4991, 0.4989, 0.4990, 0.4988]
}

# Calculate averages
avg_model1 = {region: sum(model1[region]) / len(model1[region]) for region in regions}
avg_model2 = {region: sum(model2[region]) / len(model2[region]) for region in regions}

# Plotting
plt.figure(figsize=(10, 6))
for region in regions:
    plt.scatter([region] * len(model1[region]), model1[region], label='Model 1' if regions[0] == region else "", 
                color='orange', alpha=0.6, marker='d')
    plt.scatter([region] * len(model2[region]), model2[region], label='Model 2' if regions[0] == region else "", 
                color='blue', alpha=0.6, marker='d')
    #plt.scatter(region, avg_model1[region], color='darkorange', marker='s', s=50)
    #plt.scatter(region, avg_model2[region], color='darkblue', marker='s', s=50)

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
#plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('RMSE')
plt.title('RMSE of the baseline models on the CESM2 test set')
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# RMSE of baseline models 1 and 2
regions_rmse = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1_rmse = {
    '14 days': [0.4766, 0.4750, 0.4752, 0.4760, 0.4755],
    '21 days': [0.4851, 0.4851, 0.4849, 0.4851, 0.4851],
    '28 days': [0.4929, 0.4920, 0.4921, 0.4927, 0.4926],
    '35 days': [0.4964, 0.4954, 0.4959, 0.4962, 0.4963],
    '42 days': [0.4979, 0.4976, 0.4977, 0.4979, 0.4981],
    '49 days': [0.4991, 0.4989, 0.4989, 0.4991, 0.4992],
    '56 days': [0.4994, 0.4989, 0.4991, 0.4993, 0.4994]
}

model2_rmse = {
    '14 days': [0.4869, 0.4872, 0.4869, 0.4870, 0.4869],
    '21 days': [0.4921, 0.4920, 0.4919, 0.4922, 0.4920],
    '28 days': [0.4954, 0.4951, 0.4956, 0.4950, 0.4950],
    '35 days': [0.4976, 0.4974, 0.4972, 0.4973, 0.4973],
    '42 days': [0.4984, 0.4984, 0.4982, 0.4981, 0.4983],
    '49 days': [0.4995, 0.4998, 0.4998, 0.4993, 0.4996],
    '56 days': [0.4991, 0.4991, 0.4989, 0.4990, 0.4988]
}

# Calculate averages for RMSE
avg_model1_rmse = {region: sum(model1_rmse[region]) / len(model1_rmse[region]) for region in regions_rmse}
avg_model2_rmse = {region: sum(model2_rmse[region]) / len(model2_rmse[region]) for region in regions_rmse}

# Accuracy of baseline models 1 and 2
regions_acc = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1_acc = {
    '14 days': [0.6272, 0.6145, 0.6239, 0.6296, 0.6201],
    '21 days': [0.5947, 0.5798, 0.5858, 0.5934, 0.5827],
    '28 days': [0.5725, 0.5629, 0.5660, 0.5667, 0.5553],
    '35 days': [0.5514, 0.5529, 0.5560, 0.5507, 0.5371],
    '42 days': [0.5375, 0.5430, 0.5452, 0.5356, 0.5230],
    '49 days': [0.5278, 0.5266, 0.5365, 0.5200, 0.5163],
    '56 days': [0.5168, 0.5182, 0.5272, 0.5129, 0.5141]
}

model2_acc = {
    '14 days': [0.5906, 0.5942, 0.5970, 0.5913, 0.5893],
    '21 days': [0.5650, 0.5730, 0.5720, 0.5696, 0.5782],
    '28 days': [0.5544, 0.5593, 0.5507, 0.5439, 0.5595],
    '35 days': [0.5493, 0.5522, 0.5365, 0.5346, 0.5484],
    '42 days': [0.5466, 0.5380, 0.5266, 0.5206, 0.5352],
    '49 days': [0.5267, 0.5357, 0.5295, 0.5183, 0.5333],
    '56 days': [0.5239, 0.5318, 0.5192, 0.5278, 0.5342]
}

# Calculate averages for Accuracy
avg_model1_acc = {region: sum(model1_acc[region]) / len(model1_acc[region]) for region in regions_acc}
avg_model2_acc = {region: sum(model2_acc[region]) / len(model2_acc[region]) for region in regions_acc}

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# RMSE Plot
for region in regions_rmse:
    ax1.scatter([region] * len(model1_rmse[region]), model1_rmse[region], label='Model 1' if regions_rmse[0] == region else "", 
                color='orange', alpha=0.6, marker='d')
    ax1.scatter([region] * len(model2_rmse[region]), model2_rmse[region], label='Model 2' if regions_rmse[0] == region else "", 
                color='blue', alpha=0.6, marker='d')
    ax1.scatter(region, avg_model1_rmse[region], color='darkorange', marker='s', s=50)
    ax1.scatter(region, avg_model2_rmse[region], color='darkblue', marker='s', s=50)
ax1.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
ax1.set_xlabel('Lead Time')
ax1.set_ylabel('RMSE')
ax1.set_title('RMSE of the baseline models on the CESM2 test set')
ax1.legend()

# Accuracy Plot
for region in regions_acc:
    ax2.scatter([region] * len(model1_acc[region]), model1_acc[region], label='Model 1' if regions_acc[0] == region else "", 
                color='orange', alpha=0.6, marker='d')
    ax2.scatter([region] * len(model2_acc[region]), model2_acc[region], label='Model 2' if regions_acc[0] == region else "", 
                color='blue', alpha=0.6, marker='d')
    ax2.scatter(region, avg_model1_acc[region], color='darkorange', marker='s', s=50)
    ax2.scatter(region, avg_model2_acc[region], color='darkblue', marker='s', s=50)
ax2.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
ax2.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)
ax2.set_xlabel('Lead Time')
ax2.set_ylabel('Accuracy')
ax2.set_title('Accuracy of the baseline models on the CESM2 test set')
ax2.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1 = {
    '14 days': [0.6272, 0.6145, 0.6239, 0.6296, 0.6201, 0.6198, 0.6198, 0.6095, 0.6248, 0.6093],
    '21 days': [0.5947, 0.5798, 0.5858, 0.5934, 0.5827, 0.5952, 0.5911, 0.5767, 0.5865, 0.5774],
    '28 days': [0.5725, 0.5629, 0.5660, 0.5667, 0.5553, 0.5750, 0.5735, 0.5625, 0.5674, 0.5577],
    '35 days': [0.5514, 0.5529, 0.5560, 0.5507, 0.5371, 0.5549, 0.5589, 0.5474, 0.5500, 0.5457],
    '42 days': [0.5375, 0.5430, 0.5452, 0.5356, 0.5230, 0.5415, 0.5383, 0.5342, 0.5380, 0.5387],
    '49 days': [0.5278, 0.5266, 0.5365, 0.5200, 0.5163, 0.5279, 0.5241, 0.5230, 0.5202, 0.5300],
    '56 days': [0.5168, 0.5182, 0.5272, 0.5129, 0.5141, 0.5241, 0.5259, 0.5208, 0.5117, 0.5234]
}
model2 = {
    '14 days': [0.5906, 0.5942, 0.5970, 0.5913, 0.5893],
    '21 days': [0.5650, 0.5730, 0.5720, 0.5696, 0.5782],
    '28 days': [0.5544, 0.5593, 0.5507, 0.5439, 0.5595],
    '35 days': [0.5493, 0.5522, 0.5365, 0.5346, 0.5484],
    '42 days': [0.5466, 0.5380, 0.5266, 0.5206, 0.5352],
    '49 days': [0.5267, 0.5357, 0.5295, 0.5183, 0.5333],
    '56 days': [0.5239, 0.5318, 0.5192, 0.5278, 0.5342]
}

# third model
model3 = {
    '14 days': [0.6380, 0.6379, 0.6374, 0.6374, 0.6375],
    '21 days': [0.6057, 0.6063, 0.6061, 0.6065, 0.6058],
    '28 days': [0.5872, 0.5878, 0.5863, 0.5865, 0.5868],
    '35 days': [0.5734, 0.5781, 0.5738, 0.5781, 0.5774],
    '42 days': [0.5608, 0.5631, 0.5614, 0.5621, 0.5631],
    '49 days': [0.5508, 0.5512, 0.5516, 0.5509, 0.5521],
    '56 days': [0.5522, 0.5586, 0.5563, 0.5499, 0.5517]
}

avg_model3 = {region: sum(model3[region]) / len(model3[region]) for region in regions}


# Calculate averages
avg_model1 = {region: sum(model1[region]) / len(model1[region]) for region in regions}
avg_model2 = {region: sum(model2[region]) / len(model2[region]) for region in regions}

# Plotting
plt.figure(figsize=(10, 6))
for region in regions:
    plt.scatter([region] * len(model1[region]), model1[region], label='Model 1' if regions[0] == region else "", 
                color='orange', alpha=0.6, marker='d')
    plt.scatter([region] * len(model2[region]), model2[region], label='Model 2' if regions[0] == region else "", 
                color='blue', alpha=0.6, marker='d')
    plt.scatter([region] * len(model3[region]), model3[region], label='Model 3' if regions[0] == region else "", 
                color='green', alpha=0.6, marker='d')
    plt.scatter(region, avg_model1[region], color='darkorange', marker='s', s=50)
    plt.scatter(region, avg_model2[region], color='darkblue', marker='s', s=50)
    plt.scatter(region, avg_model3[region], color='green', marker='s', s=50)

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.title('CESM2 Accuracy of Model 1, 2 and 3')
plt.legend()

# Show plot
plt.show()

# %%
# Accuracy of baseline models 1, 2 and model 3 and model GDBT

import matplotlib.pyplot as plt

# Data
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1 = {
    '14 days': [0.6272, 0.6145, 0.6239, 0.6296, 0.6201, 0.6198, 0.6198, 0.6095, 0.6248, 0.6093],
    '21 days': [0.5947, 0.5798, 0.5858, 0.5934, 0.5827, 0.5952, 0.5911, 0.5767, 0.5865, 0.5774],
    '28 days': [0.5725, 0.5629, 0.5660, 0.5667, 0.5553, 0.5750, 0.5735, 0.5625, 0.5674, 0.5577],
    '35 days': [0.5514, 0.5529, 0.5560, 0.5507, 0.5371, 0.5549, 0.5589, 0.5474, 0.5500, 0.5457],
    '42 days': [0.5375, 0.5430, 0.5452, 0.5356, 0.5230, 0.5415, 0.5383, 0.5342, 0.5380, 0.5387],
    '49 days': [0.5278, 0.5266, 0.5365, 0.5200, 0.5163, 0.5279, 0.5241, 0.5230, 0.5202, 0.5300],
    '56 days': [0.5168, 0.5182, 0.5272, 0.5129, 0.5141, 0.5241, 0.5259, 0.5208, 0.5117, 0.5234]
}
model2 = {
    '14 days': [0.5906, 0.5942, 0.5970, 0.5913, 0.5893],
    '21 days': [0.5650, 0.5730, 0.5720, 0.5696, 0.5782],
    '28 days': [0.5544, 0.5593, 0.5507, 0.5439, 0.5595],
    '35 days': [0.5493, 0.5522, 0.5365, 0.5346, 0.5484],
    '42 days': [0.5466, 0.5380, 0.5266, 0.5206, 0.5352],
    '49 days': [0.5267, 0.5357, 0.5295, 0.5183, 0.5333],
    '56 days': [0.5239, 0.5318, 0.5192, 0.5278, 0.5342]
}
model3 = {
    '14 days': [0.6380, 0.6379, 0.6374, 0.6374, 0.6375],
    '21 days': [0.6057, 0.6063, 0.6061, 0.6065, 0.6058],
    '28 days': [0.5872, 0.5878, 0.5863, 0.5865, 0.5868],
    '35 days': [0.5734, 0.5781, 0.5738, 0.5781, 0.5774],
    '42 days': [0.5608, 0.5631, 0.5614, 0.5621, 0.5631],
    '49 days': [0.5508, 0.5512, 0.5516, 0.5509, 0.5521],
    '56 days': [0.5522, 0.5586, 0.5563, 0.5499, 0.5517]
}
model4 = {
    '14 days': [0.6431, 0.6409, 0.6407, 0.6433, 0.6397],
    '21 days': [0.6102, 0.6109, 0.6107, 0.6115, 0.6102],
    '28 days': [0.5901, 0.5889, 0.5885, 0.5909, 0.5880],
    '35 days': [0.5724, 0.5734, 0.5718, 0.5755, 0.5737],
    '42 days': [0.5602, 0.5606, 0.5632, 0.5621, 0.5601],
    '49 days': [0.5534, 0.5529, 0.5541, 0.5517, 0.5548],
    '56 days': [0.5561, 0.5572, 0.5548, 0.5570, 0.5584]
}

# Calculate averages
avg_model1 = {region: sum(model1[region]) / len(model1[region]) for region in regions}
avg_model2 = {region: sum(model2[region]) / len(model2[region]) for region in regions}
avg_model3 = {region: sum(model3[region]) / len(model3[region]) for region in regions}
avg_model4 = {region: sum(model4[region]) / len(model4[region]) for region in regions}

# Plotting
plt.figure(figsize=(10, 6))
for region in regions:
    plt.scatter([region] * len(model1[region]), model1[region], label='Model 1' if region == regions[0] else "", 
                color='orange', alpha=0.6, marker='d')
    plt.scatter([region] * len(model2[region]), model2[region], label='Model 2' if region == regions[0] else "", 
                color='blue', alpha=0.6, marker='d')
    plt.scatter([region] * len(model3[region]), model3[region], label='Model 3' if region == regions[0] else "", 
                color='green', alpha=0.6, marker='d')
    plt.scatter([region] * len(model4[region]), model4[region], label='Model GDBT' if region == regions[0] else "", 
                color='purple', alpha=0.6, marker='d')
    plt.scatter(region, avg_model1[region], color='darkorange', marker='s', s=50)
    plt.scatter(region, avg_model2[region], color='darkblue', marker='s', s=50)
    plt.scatter(region, avg_model3[region], color='darkgreen', marker='s', s=50)
    plt.scatter(region, avg_model4[region], color='darkviolet', marker='s', s=50)

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.title('Accuracy of Models 1, 2, 3, and GDBT on the CESM2 test set')
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']

# CESM2 Dataset Averages
model1_cesm2 = [0.623, 0.587, 0.565, 0.550, 0.537, 0.525, 0.518]
model2_cesm2 = [0.592, 0.572, 0.554, 0.544, 0.533, 0.529, 0.527]
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
model4_cesm2 = [0.642, 0.611, 0.590, 0.573, 0.562, 0.553, 0.556]  # XGBoost

# ERA5 Dataset Averages
model1_era5 = [0.606, 0.582, 0.555, 0.536, 0.518, 0.512, 0.512]
model2_era5 = [0.570, 0.556, 0.539, 0.529, 0.506, 0.496, 0.510]
model3_era5 = [0.607, 0.582, 0.562, 0.533, 0.510, 0.499, 0.510]
model4_era5 = [0.608, 0.577, 0.554, 0.532, 0.513, 0.504, 0.506]  # XGBoost

# Plotting
plt.figure(figsize=(12, 6))

# Model 1 (lighter and darker tones)
plt.plot(regions, model1_cesm2, marker='o', label='Model 1 (CESM2)', color='#FF6384', linewidth=2)
plt.plot(regions, model1_era5, marker='o', label='Model 1 (ERA5)', color='#A52A2A', linewidth=2)  # Darker red

# Model 2 (lighter and darker tones)
plt.plot(regions, model2_cesm2, marker='o', label='Model 2 (CESM2)', color='#36A2EB', linewidth=2)
plt.plot(regions, model2_era5, marker='o', label='Model 2 (ERA5)', color='#104E8B', linewidth=2)  # Darker blue

# Model 3 (lighter and darker tones)
plt.plot(regions, model3_cesm2, marker='o', label='Model 3 (CESM2)', color='#FFCE56', linewidth=2)
plt.plot(regions, model3_era5, marker='o', label='Model 3 (ERA5)', color='#BFAF32', linewidth=2)  # Darker yellow

# Model 4 (XGBoost, lighter and darker tones)
plt.plot(regions, model4_cesm2, marker='o', label='Model 4 (XGBoost, CESM2)', color='#4BC0C0', linewidth=2)
plt.plot(regions, model4_era5, marker='o', label='Model 4 (XGBoost, ERA5)', color='#2E8B8B', linewidth=2)  # Darker teal

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=0.5)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.title('Accuracy of Baseline Models on CESM2 and ERA5 Test Sets')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']

# CESM2 Dataset Averages
model1_cesm2 = [0.623, 0.587, 0.565, 0.550, 0.537, 0.525, 0.518]
model2_cesm2 = [0.592, 0.572, 0.554, 0.544, 0.533, 0.529, 0.527]
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
model4_cesm2 = [0.642, 0.611, 0.590, 0.573, 0.562, 0.553, 0.556]  # XGBoost

# ERA5 Dataset Averages
model1_era5 = [0.606, 0.582, 0.555, 0.536, 0.518, 0.512, 0.512]
model2_era5 = [0.570, 0.556, 0.539, 0.529, 0.506, 0.496, 0.510]
model3_era5 = [0.607, 0.582, 0.562, 0.533, 0.510, 0.499, 0.510]
model4_era5 = [0.608, 0.577, 0.554, 0.532, 0.513, 0.504, 0.506]  # XGBoost

# Combine data for grouped bar plot
data = [
    model1_cesm2,
    model1_era5,
    model2_cesm2,
    model2_era5,
    model3_cesm2,
    model3_era5,
    model4_cesm2,
    model4_era5
]
labels = [
    'Model 1 CESM2', 'Model 1 ERA5',
    'Model 2 CESM2', 'Model 2 ERA5',
    'Model 3 CESM2', 'Model 3 ERA5',
    'Model 4 (XGBoost) CESM2', 'Model 4 (XGBoost) ERA5'
]
colors = ['#FF6384', '#A52A2A', '#36A2EB', '#104E8B', '#FFCE56', '#BFAF32', '#4BC0C0', '#2E8B8B']
hatch = ['', '//', '', '//', '', '//', '', '//']

x = np.arange(len(regions))  # the label locations
width = 0.1  # the width of the bars

plt.figure(figsize=(14, 7))
for idx, (model, label) in enumerate(zip(data, labels)):
    plt.bar(x + idx * width - (width * 3.5), model, width, label=label, color=colors[idx], hatch=hatch[idx])

plt.title('Average Accuracy Across Lead Times for CESM2 and ERA5 Datasets')
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.xticks(x, regions)
plt.ylim(0.45, 0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']

# CESM2 Dataset Averages
model1_cesm2 = [0.623, 0.587, 0.565, 0.550, 0.537, 0.525, 0.518]
model2_cesm2 = [0.592, 0.572, 0.554, 0.544, 0.533, 0.529, 0.527]
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
model4_cesm2 = [0.642, 0.611, 0.590, 0.573, 0.562, 0.553, 0.556]  # XGBoost

# ERA5 Dataset Averages
model1_era5 = [0.606, 0.582, 0.555, 0.536, 0.518, 0.512, 0.512]
model2_era5 = [0.570, 0.556, 0.539, 0.529, 0.506, 0.496, 0.510]
model3_era5 = [0.607, 0.582, 0.562, 0.533, 0.510, 0.499, 0.510]
model4_era5 = [0.608, 0.577, 0.554, 0.532, 0.513, 0.504, 0.506]  # XGBoost

# Figure 1: Models 1 and 2
plt.figure(figsize=(14, 7))
x = np.arange(len(regions))  # the label locations
width = 0.2  # the width of the bars

plt.bar(x - width/2, model1_cesm2, width, label='Model 1 CESM2', color='#FF6384')
plt.bar(x - width/2, model1_era5, width, label='Model 1 ERA5', color='#A52A2A', hatch='//')
plt.bar(x + width/2, model2_cesm2, width, label='Model 2 CESM2', color='#36A2EB')
plt.bar(x + width/2, model2_era5, width, label='Model 2 ERA5', color='#104E8B', hatch='//')

plt.title('Average Accuracy for Models 1 and 2 on CESM2 and ERA5 Datasets')
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.xticks(x, regions)
plt.ylim(0.45, 0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# Figure 2: Models 3 and 4
plt.figure(figsize=(14, 7))
x = np.arange(len(regions))  # the label locations
width = 0.2  # the width of the bars

plt.bar(x - width/2, model3_cesm2, width, label='Model 3 CESM2', color='#FFCE56')
plt.bar(x - width/2, model3_era5, width, label='Model 3 ERA5', color='#BFAF32', hatch='//')
plt.bar(x + width/2, model4_cesm2, width, label='Model 4 (XGBoost) CESM2', color='#4BC0C0')
plt.bar(x + width/2, model4_era5, width, label='Model 4 (XGBoost) ERA5', color='#2E8B8B', hatch='//')

plt.title('Average Accuracy for Models 3 and 4 on CESM2 and ERA5 Datasets')
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.xticks(x, regions)
plt.ylim(0.45, 0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']

# CESM2 Dataset Averages
model1_cesm2 = [0.623, 0.587, 0.565, 0.550, 0.537, 0.525, 0.518]
model2_cesm2 = [0.592, 0.572, 0.554, 0.544, 0.533, 0.529, 0.527]
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
model4_cesm2 = [0.642, 0.611, 0.590, 0.573, 0.562, 0.553, 0.556]  # XGBoost

# ERA5 Dataset Averages
model1_era5 = [0.606, 0.582, 0.555, 0.536, 0.518, 0.512, 0.512]
model2_era5 = [0.570, 0.556, 0.539, 0.529, 0.506, 0.496, 0.510]
model3_era5 = [0.607, 0.582, 0.562, 0.533, 0.510, 0.499, 0.510]
model4_era5 = [0.608, 0.577, 0.554, 0.532, 0.513, 0.504, 0.506]  # XGBoost

# Combine data for grouped bar plot
x = np.arange(len(regions))  # the label locations
width = 0.2  # the width of the bars

# Plotting
plt.figure(figsize=(14, 7))

plt.bar(x - 1.5 * width, model1_cesm2, width, label='Model 1 CESM2', color='#FF6384')
plt.bar(x - 1.5 * width, model1_era5, width, label='Model 1 ERA5', color='#A52A2A', hatch='//')
plt.bar(x - 0.5 * width, model2_cesm2, width, label='Model 2 CESM2', color='#36A2EB')
plt.bar(x - 0.5 * width, model2_era5, width, label='Model 2 ERA5', color='#104E8B', hatch='//')
plt.bar(x + 0.5 * width, model3_cesm2, width, label='Model 3 CESM2', color='#FFCE56')
plt.bar(x + 0.5 * width, model3_era5, width, label='Model 3 ERA5', color='#BFAF32', hatch='//')
plt.bar(x + 1.5 * width, model4_cesm2, width, label='GDBT CESM2', color='#4BC0C0')
plt.bar(x + 1.5 * width, model4_era5, width, label='GDBT ERA5', color='#2E8B8B', hatch='//')

plt.title('Average Accuracy for all models CESM2 and ERA5 Datasets')
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.xticks(x, regions, rotation=45)  # Rotate x-axis labels for better readability
plt.ylim(0.45, 0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']

# CESM2 Dataset Averages
model1_cesm2 = [0.623, 0.587, 0.565, 0.550, 0.537, 0.525, 0.518]
model2_cesm2 = [0.592, 0.572, 0.554, 0.544, 0.533, 0.529, 0.527]
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
model4_cesm2 = [0.642, 0.611, 0.590, 0.573, 0.562, 0.553, 0.556]  # GDBT

# ERA5 Dataset Averages
model1_era5 = [0.606, 0.582, 0.555, 0.536, 0.518, 0.512, 0.512]
model2_era5 = [0.570, 0.556, 0.539, 0.529, 0.506, 0.496, 0.510]
model3_era5 = [0.607, 0.582, 0.562, 0.533, 0.510, 0.499, 0.510]
model4_era5 = [0.608, 0.577, 0.554, 0.532, 0.513, 0.504, 0.506]  # GDBT

# Combine data for grouped bar plot
x = np.arange(len(regions))  # the label locations
width = 0.2  # the width of the bars

# Plotting
plt.figure(figsize=(16, 8))

plt.bar(x - 1.5 * width, model1_cesm2, width, label='M1 CESM2', color='#FF6384')
plt.bar(x - 1.5 * width, model1_era5, width, label='M1 ERA5', color='#A52A2A', hatch='//')
plt.bar(x - 0.5 * width, model2_cesm2, width, label='M2 CESM2', color='#36A2EB')
plt.bar(x - 0.5 * width, model2_era5, width, label='M2 ERA5', color='#104E8B', hatch='//')
plt.bar(x + 0.5 * width, model3_cesm2, width, label='M3 CESM2', color='#FFCE56')
plt.bar(x + 0.5 * width, model3_era5, width, label='M3 ERA5', color='#BFAF32', hatch='//')
plt.bar(x + 1.5 * width, model4_cesm2, width, label='GDBT CESM2', color='#4BC0C0')
plt.bar(x + 1.5 * width, model4_era5, width, label='GDBT ERA5', color='#2E8B8B', hatch='//')

plt.title('Average Accuracy for All Models on CESM2 and ERA5 Datasets')
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.xticks(x, regions, rotation=45)  # Rotate x-axis labels for better readability
plt.ylim(0.45, 0.7)
plt.grid(True, axis='y', alpha=0.3)

# Customize legend inside the graph
# Customize legend inside the graph
plt.legend(loc='upper right', ncol=4, fontsize=10, 
           frameon=True, edgecolor='black', title='Models', title_fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Comparison of Model 1 with M3 Settings vs. Model 3 CESM2

import matplotlib.pyplot as plt

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model1_m3_settings = [0.640, 0.608, 0.588, 0.573, 0.554, 0.536, 0.509]
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
baseline_model1 = [0.6231, 0.5873, 0.5647, 0.5496, 0.5369, 0.5254, 0.5178]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(regions, baseline_model1, marker='o', label='Model 1 Baseline settings', color='#FF6384', linewidth=2)
plt.plot(regions, model1_m3_settings, marker='o', label='Model 1 Fine-tuned Settings', color="#DA002F", linewidth=2)
plt.plot(regions, model3_cesm2, marker='o', label='Model 3', color='#36A2EB', linewidth=2)

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=2)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.title('Comparison of Average Accuracy: Model 1 with Model 3 Settings vs. Model 3 on the CESM2 test set')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show plot
plt.tight_layout()
plt.show()

# %%
# Comparison of Model 3 with M1 Settings vs. Model 1 CESM2

import matplotlib.pyplot as plt

# Data (averages rounded to 3 decimal places)
regions = ['14 days', '21 days', '28 days', '35 days', '42 days', '49 days', '56 days']
model3_cesm2 = [0.638, 0.606, 0.587, 0.576, 0.562, 0.551, 0.554]
model3_m1_settings = [0.625, 0.595, 0.572, 0.554, 0.542, 0.530, 0.531]
model1_cesm2 = [0.623, 0.587, 0.565, 0.550, 0.537, 0.525, 0.518]


# Plotting
plt.figure(figsize=(10, 6))

plt.plot(regions, model1_cesm2, marker='o', label='Model 1 Baseline Settings', color='#FF6384', linewidth=2)
plt.plot(regions, model3_m1_settings, marker='o', label='Model 3 Baseline Settings', color="#006EB7", linewidth=2)
plt.plot(regions, model3_cesm2, marker='o', label='Model 3 Fine-tuned', color="#A5D1FF", linewidth=2)

# Adding a reference line at 0.5 accuracy
plt.grid(True, which='both', linestyle=':', linewidth=0.7, alpha=0.7)
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=2)

# Labels and title
plt.xlabel('Lead Time')
plt.ylabel('Accuracy')
plt.title('Comparison of Average Accuracy: Model 3 with Model 1 Settings vs. Model 1 on the CESM2 test set')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show plot
plt.tight_layout()
plt.show()

# %%
# confidence graph for model 1

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data is already loaded and in the correct format, so no need to split or rename columns

# Convert numeric columns to float
for col in data.columns:
    if 'accuracy' in col or col in ['lead', 'seed']:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# Unique lead times
lead_times = data['lead'].unique()

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod']

# Plotting
plt.figure(figsize=(10, 6))

for i, lead in enumerate(lead_times):
    # Plot each row for the current lead time
    lead_data = data[data['lead'] == lead]
    for _, row in lead_data.iterrows():
        accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
        x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100 (10 bins)
        plt.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=1)

    # Calculate and plot the average for the current lead time
    avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
    plt.plot(range(10, 110, 10), avg_accuracies, label=f'Lead {lead} Avg', color=dark_colors[i % len(colors)], linewidth=2)

# Labels and title
plt.xlabel('Percent Most Confident')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Confidence by Lead Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Accurcay vs Confidence by Lead Time with Rectangle Highlight model 1

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle

# Convert numeric columns to float
for col in data.columns:
    if 'accuracy' in col or col in ['lead', 'seed']:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# Unique lead times
lead_times = data['lead'].unique()

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow', 'cyan']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod', 'darkcyan']

# Plotting
plt.figure(figsize=(10, 6))

for i, lead in enumerate(lead_times):
    # Plot all rows for the current lead time
    lead_data = data[data['lead'] == lead]
    for _, row in lead_data.iterrows():
        accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
        x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100
        plt.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=0.5, linestyle='--')

    # Calculate and plot the average for the current lead time
    avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
    plt.plot(range(10, 110, 10), avg_accuracies, label=f'{lead} days', color=dark_colors[i % len(colors)], linewidth=4)

# Set x-axis limits to match the data bins
plt.xlim(10, 100)

# Set y-axis to start at 0.45 (below the minimum data value)
plt.ylim(0.45, plt.ylim()[1])

# Add grid lines in the background
plt.grid(True, which='both', zorder=0)

# Add a rectangle around the top 20% confidence (bins 80 to 100 on x-axis), pushed to the front
plt.gca().add_patch(
    Rectangle(
        (80, 0.5),   # (x, y) lower left corner: x=80 (80% confidence), y=0.5
        20,          # width: from 80 to 100 (100-80)
        0.32,         # height: from 0.5 to 0.8 (0.8-0.5)
        fill=False,
        edgecolor='black',
        linewidth=3,
        linestyle='-',
        zorder=10,    # Higher zorder to bring it to the front
    )
)

# Set x-axis ticks and reverse labels without affecting data
plt.xticks(range(10, 110, 10))
plt.gca().set_xticklabels(range(90, -10, -10))

# Labels and title
plt.xlabel('Percent Most Confident')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Confidence by Lead Time')
plt.legend()
plt.show()

# %%
# Accurcay vs Confidence by Lead Time with Rectangle Highlight model 1
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle


# load data with correct separator
data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model2_confidence_bins.csv", sep=';')

# Convert numeric columns to float
for col in data.columns:
    if 'accuracy' in col or col in ['lead', 'seed']:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# Unique lead times
lead_times = data['lead'].unique()

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow', 'cyan']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod', 'darkcyan']

# Plotting
plt.figure(figsize=(10, 6))

for i, lead in enumerate(lead_times):
    # Plot all rows for the current lead time
    lead_data = data[data['lead'] == lead]
    for _, row in lead_data.iterrows():
        accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
        x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100
        plt.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=0.5, linestyle='--')

    # Calculate and plot the average for the current lead time
    avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
    plt.plot(range(10, 110, 10), avg_accuracies, label=f'{lead} days', color=dark_colors[i % len(colors)], linewidth=4)

# Set x-axis limits to match the data bins
plt.xlim(10, 100)

# Set y-axis to start at 0.45 (below the minimum data value)
plt.ylim(0.45, plt.ylim()[1])

# Add grid lines in the background
plt.grid(True, which='both', zorder=0)

# Add a rectangle around the top 20% confidence (bins 80 to 100 on x-axis), pushed to the front
plt.gca().add_patch(
    Rectangle(
        (80, 0.5),   # (x, y) lower left corner: x=80 (80% confidence), y=0.5
        20,          # width: from 80 to 100 (100-80)
        0.22,         # height: from 0.5 to 0.8 (0.8-0.5)
        fill=False,
        edgecolor='black',
        linewidth=3,
        linestyle='-',
        zorder=10,    # Higher zorder to bring it to the front
    )
)

# Set x-axis ticks and reverse labels without affecting data
plt.xticks(range(10, 110, 10))
plt.gca().set_xticklabels(range(90, -10, -10))

# Labels and title
plt.xlabel('Percent Most Confident')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Confidence by Lead Time model 2')
plt.legend()
plt.show()

# %%
# Accurcay vs Confidence by Lead Time with Rectangle Highlight model 3
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle


# load data with correct separator
data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model1_v050_confidence_bins_CESM2.csv", sep=';')

# Convert numeric columns to float
for col in data.columns:
    if 'accuracy' in col or col in ['lead', 'seed']:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# Unique lead times
lead_times = data['lead'].unique()

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow', 'cyan']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod', 'darkcyan']

# Plotting
plt.figure(figsize=(10, 6))

for i, lead in enumerate(lead_times):
    # Plot all rows for the current lead time
    lead_data = data[data['lead'] == lead]
    for _, row in lead_data.iterrows():
        accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
        x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100
        plt.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=0.5, linestyle='--')

    # Calculate and plot the average for the current lead time
    avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
    plt.plot(range(10, 110, 10), avg_accuracies, label=f'{lead} days', color=dark_colors[i % len(colors)], linewidth=4)

# Set x-axis limits to match the data bins
plt.xlim(10, 100)

# Set y-axis to start at 0.45 (below the minimum data value)
plt.ylim(0.45, plt.ylim()[1])

# Add grid lines in the background
plt.grid(True, which='both', zorder=0)

# Add a rectangle around the top 20% confidence (bins 80 to 100 on x-axis), pushed to the front
plt.gca().add_patch(
    Rectangle(
        (80, 0.5),   # (x, y) lower left corner: x=80 (80% confidence), y=0.5
        20,          # width: from 80 to 100 (100-80)
        0.32,         # height: from 0.5 to 0.8 (0.8-0.5)
        fill=False,
        edgecolor='black',
        linewidth=3,
        linestyle='-',
        zorder=10,    # Higher zorder to bring it to the front
    )
)

# Set x-axis ticks and reverse labels without affecting data
plt.xticks(range(10, 110, 10))
plt.gca().set_xticklabels(range(90, -10, -10))

# Labels and title
plt.xlabel('Percent Most Confident')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Confidence by Lead Time model 3')
plt.legend()
plt.show()

# %%
# Accurcay vs Confidence by Lead Time with Rectangle Highlight model 3
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle


# load data with correct separator
data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_XGboost_cesm2_confidence_bins.csv", sep=';')

# Convert numeric columns to float
for col in data.columns:
    if 'accuracy' in col or col in ['lead', 'seed']:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# Unique lead times
lead_times = data['lead'].unique()

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow', 'cyan']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod', 'darkcyan']

# Plotting
plt.figure(figsize=(10, 6))

for i, lead in enumerate(lead_times):
    # Plot all rows for the current lead time
    lead_data = data[data['lead'] == lead]
    for _, row in lead_data.iterrows():
        accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
        x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100
        plt.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=0.5, linestyle='--')

    # Calculate and plot the average for the current lead time
    avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
    plt.plot(range(10, 110, 10), avg_accuracies, label=f'{lead} days', color=dark_colors[i % len(colors)], linewidth=4)

# Set x-axis limits to match the data bins
plt.xlim(10, 100)

# Set y-axis to start at 0.45 (below the minimum data value)
plt.ylim(0.45, plt.ylim()[1])

# Add grid lines in the background
plt.grid(True, which='both', zorder=0)

# Add a rectangle around the top 20% confidence (bins 80 to 100 on x-axis), pushed to the front
plt.gca().add_patch(
    Rectangle(
        (80, 0.5),   # (x, y) lower left corner: x=80 (80% confidence), y=0.5
        20,          # width: from 80 to 100 (100-80)
        0.335,         # height: from 0.5 to 0.8 (0.8-0.5)
        fill=False,
        edgecolor='black',
        linewidth=3,
        linestyle='-',
        zorder=10,    # Higher zorder to bring it to the front
    )
)

# Set x-axis ticks and reverse labels without affecting data
plt.xticks(range(10, 110, 10))
plt.gca().set_xticklabels(range(90, -10, -10))

# Labels and title
plt.xlabel('Percent Most Confident')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Confidence by Lead Time model GDBT')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle


# load data with correct separator
data_model1 = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model1_confidence_bins.csv", sep=';')
data_model2 = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model2_confidence_bins.csv", sep=';')
data_model3 = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model1_v050_confidence_bins_CESM2.csv", sep=';')
data_gdbt = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_XGboost_cesm2_confidence_bins.csv", sep=';')

# Assuming data DataFrames for each model (replace with your actual data)
data_models = {
    'Model 1': data_model1,  # Replace with Model 1 data
    'Model 2': data_model2,  # Replace with Model 2 data
    'Model 3': data_model3,  # Replace with Model 3 data
    'GDBT Model': data_gdbt        # Replace with GDBT/XGBoost data
}

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow', 'cyan']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod', 'darkcyan']

# Create a figure with 4 subplots vertically stacked
fig, axes = plt.subplots(4, 1, figsize=(10, 16), sharex=True, sharey=True)

# Manually set rectangle heights for each model based on observed data
rectangle_heights = {
    'Model 1': 0.35,  # Estimated from image: top ~0.78, bottom 0.5
    'Model 2': 0.35,  # Estimated from image: top ~0.72, bottom 0.5
    'Model 3': 0.35,  # Estimated from image: top ~0.74, bottom 0.5
    'GDBT Model': 0.35      # Estimated from image: top ~0.76, bottom 0.5
}

for idx, (model_name, data) in enumerate(data_models.items()):
    ax = axes[idx]

    # Convert numeric columns to float
    for col in data.columns:
        if 'accuracy' in col or col in ['lead', 'seed']:
            data[col] = pd.to_numeric(data[col], errors='coerce')

    # Unique lead times
    lead_times = data['lead'].unique()

    # Plotting for each lead time
    for i, lead in enumerate(lead_times):
        # Plot all rows for the current lead time
        lead_data = data[data['lead'] == lead]
        for _, row in lead_data.iterrows():
            accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
            x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100
            ax.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=0.5, linestyle='--')

        # Calculate and plot the average for the current lead time
        avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
        ax.plot(range(10, 110, 10), avg_accuracies, label=f'{lead} days', color=dark_colors[i % len(colors)], linewidth=4)

    # Add a rectangle around the top 20% confidence (bins 80 to 100 on x-axis) with manual height
    ax.add_patch(
        Rectangle(
            (80, 0.5),   # (x, y) lower left corner: x=80 (80% confidence), y=0.5
            20,          # width: from 80 to 100 (100-80)
            rectangle_heights[model_name],  # Manual height for each model
            fill=False,
            edgecolor='black',
            linewidth=3,
            linestyle='-',
            zorder=10,    # Higher zorder to bring it to the front
        )
    )

    # Set x-axis limits to match the data bins
    ax.set_xlim(10, 100)

    # Set y-axis to start at 0.45
    ax.set_ylim(0.45, ax.get_ylim()[1])

    # Add grid lines in the background
    ax.grid(True, which='both', zorder=0)

    # Set x-axis ticks and reverse labels
    ax.set_xticks(range(10, 110, 10))
    ax.set_xticklabels(range(90, -10, -10))

    # Title for each subplot
    ax.set_title(f'Accuracy vs Confidence for {model_name}')

    # Add individual legend for each subplot
    ax.legend(loc='upper left', bbox_to_anchor=(0.0, 1.0), ncol=4, fontsize=8, frameon=True, edgecolor='black')

# Adjust layout to prevent overlap
plt.tight_layout()

# Set common labels
fig.text(0.5, 0.04, 'Percent Most Confident', ha='center')
fig.text(0.04, 0.5, 'Accuracy (%)', va='center', rotation='vertical')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle

# Assuming data DataFrames for each model (replace with your actual data)
data_models = {
    'Model 1': data_model1,  # Replace with Model 1 data
    'Model 2': data_model2,  # Replace with Model 2 data
    'Model 3': data_model3,  # Replace with Model 3 data
    'GDBT': data_gdbt        # Replace with GDBT/XGBoost data
}

# Define colors and darker shades for averages
colors = ['blue', 'orange', 'red', 'purple', 'green', 'yellow', 'cyan']
dark_colors = ['darkblue', 'darkorange', 'darkred', 'indigo', 'darkgreen', 'goldenrod', 'darkcyan']

# Create a figure with 4 subplots vertically stacked
fig, axes = plt.subplots(4, 1, figsize=(10, 16), sharex=True, sharey=True)

# Manually set rectangle heights for each model based on observed data
rectangle_heights = {
    'Model 1': 0.28,  # Estimated from image: top ~0.78, bottom 0.5
    'Model 2': 0.22,  # Estimated from image: top ~0.72, bottom 0.5
    'Model 3': 0.24,  # Estimated from image: top ~0.74, bottom 0.5
    'GDBT': 0.26      # Estimated from image: top ~0.76, bottom 0.5
}

for idx, (model_name, data) in enumerate(data_models.items()):
    ax = axes[idx]

    # Convert numeric columns to float
    for col in data.columns:
        if 'accuracy' in col or col in ['lead', 'seed']:
            data[col] = pd.to_numeric(data[col], errors='coerce')

    # Unique lead times
    lead_times = data['lead'].unique()

    # Plotting for each lead time
    for i, lead in enumerate(lead_times):
        # Plot all rows for the current lead time
        lead_data = data[data['lead'] == lead]
        for _, row in lead_data.iterrows():
            accuracies = [row[f'bin_{j}_accuracy'] for j in range(1, 11)]
            x = range(10, 110, 10)  # Confidence bins: 10, 20, ..., 100
            ax.plot(x, accuracies, color=colors[i % len(colors)], alpha=0.5, linewidth=0.5, linestyle='--')

        # Calculate and plot the average for the current lead time
        avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean()
        ax.plot(range(10, 110, 10), avg_accuracies, label=f'{lead} days', color=dark_colors[i % len(colors)], linewidth=4)

    # Add a rectangle around the top 20% confidence (bins 80 to 100 on x-axis) with manual height
    ax.add_patch(
        Rectangle(
            (80, 0.5),   # (x, y) lower left corner: x=80 (80% confidence), y=0.5
            20,          # width: from 80 to 100 (100-80)
            rectangle_heights[model_name],  # Manual height for each model
            fill=False,
            edgecolor='black',
            linewidth=3,
            linestyle='-',
            zorder=10,    # Higher zorder to bring it to the front
        )
    )

    # Set x-axis limits to match the data bins
    ax.set_xlim(10, 100)

    # Set y-axis to start at 0.45
    ax.set_ylim(0.45, ax.get_ylim()[1])

    # Add grid lines in the background
    ax.grid(True, which='both', zorder=0)

    # Set x-axis ticks and reverse labels
    ax.set_xticks(range(10, 110, 10))
    ax.set_xticklabels(range(90, -10, -10))

    # Title for each subplot
    ax.set_title(f'Accuracy vs Confidence for {model_name}')

    # Add individual legend for each subplot
    ax.legend(loc='upper left', bbox_to_anchor=(0.0, 1.0), ncol=4, fontsize=8, frameon=True, edgecolor='black')

# Adjust layout to prevent overlap
plt.tight_layout()

# Set common labels
fig.text(0.5, 0.04, 'Percent Most Confident', ha='center')
fig.text(0.04, 0.5, 'Accuracy (%)', va='center', rotation='vertical')

plt.show()

# %%
import pandas as pd
import numpy as np

# Assuming data DataFrames for each model (replace with your actual data)
data_models = {
    'Model 1': data_model1,  # Replace with Model 1 data
    'Model 2': data_model2,  # Replace with Model 2 data
    'Model 3': data_model3,  # Replace with Model 3 data
    'GDBT': data_gdbt        # Replace with GDBT/XGBoost data
}

# Initialize a dictionary to store averages for each model
averages_dict = {}

# Lead times
lead_times = [14, 21, 28, 35, 42, 49, 56]

for model_name, data in data_models.items():
    # Convert numeric columns to float
    for col in data.columns:
        if 'accuracy' in col or col in ['lead', 'seed']:
            data[col] = pd.to_numeric(data[col], errors='coerce')

    # Calculate averages for each lead time
    model_averages = {}
    for lead in lead_times:
        lead_data = data[data['lead'] == lead]
        if not lead_data.empty:
            avg_accuracies = lead_data[[f'bin_{j}_accuracy' for j in range(1, 11)]].mean().mean()  # Average across all bins
            model_averages[lead] = avg_accuracies

    averages_dict[model_name] = model_averages

# Create a DataFrame from the averages
df_averages = pd.DataFrame(averages_dict).T  # Transpose to have models as rows
df_averages.index.name = 'Model'
df_averages.columns = [f'Lead {lt} days' for lt in lead_times]

# Save to CSV
df_averages.to_csv('C:/Users/31610/Documents/UvA/Master thesis/Results/model_averages.csv')

print("Averages have been saved to 'model_averages.csv'")
print(df_averages)
# Out:
# Averages have been saved to 'model_averages.csv'
#          Lead 14 days  Lead 21 days  Lead 28 days  Lead 35 days  Lead 42 days  \
# Model
# Model 1      0.632518      0.606694      0.576697      0.556639      0.539998
# Model 2      0.594461      0.576216      0.562703      0.545334      0.536976
# Model 3      0.637634      0.606083      0.586956      0.576186      0.562147
# GDBT         0.641508      0.610665      0.589257      0.573332      0.561213
#
#          Lead 49 days  Lead 56 days
# Model
# Model 1      0.526763      0.522657
# Model 2      0.523638      0.529189
# Model 3      0.551350      0.553787
# GDBT         0.553347      0.556667

# %%
import pandas as pd
import numpy as np

# load data with correct separator
data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model1_confidence_bins.csv", sep=';')
#data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model2_confidence_bins.csv", sep=';')
#data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_model1_v050_confidence_bins_CESM2.csv", sep=';')
#data = pd.read_csv("C:/Users/31610/Documents/UvA/Master thesis/Results/accuracy_XGboost_cesm2_confidence_bins.csv", sep=';')

# Convert numeric columns to float, handling errors
numeric_columns = [col for col in data.columns if 'accuracy' in col or col in ['lead', 'seed']]
for col in numeric_columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Group by 'experiment' to treat each as a potential model
experiments = data['experiment'].unique()

# Initialize a dictionary to store averages for each experiment
averages_dict = {}

for exp in experiments:
    # Filter data for the current experiment
    exp_data = data[data['experiment'] == exp]
    
    # Calculate averages for each confidence bin across all leads and seeds
    bin_columns = [f'bin_{j}_accuracy' for j in range(1, 11)]  # bins 1 to 10 (10% to 100%)
    avg_accuracies = exp_data[bin_columns].mean()  # Mean across all rows (all leads and seeds)
    averages_dict[exp] = avg_accuracies

# Create a DataFrame from the averages
df_averages = pd.DataFrame(averages_dict).T  # Transpose to have experiments as rows
df_averages.index.name = 'Experiment'
df_averages.columns = [f'Bin {i * 10}%' for i in range(1, 11)]  # Rename columns to Bin 10% to Bin 100%

# Save to CSV
df_averages.to_csv('C:/Users/31610/Documents/UvA/Master thesis/Results/model_1_bin_averages.csv')

print('C:/Users/31610/Documents/UvA/Master thesis/Results/model_gdbt_bin_averages.csv')
print(df_averages)
# Out:
# C:/Users/31610/Documents/UvA/Master thesis/Results/model_gdbt_bin_averages.csv
#                 Bin 10%   Bin 20%   Bin 30%   Bin 40%   Bin 50%   Bin 60%  \
# Experiment
# exp_1/exp_100  0.515084  0.539944  0.567297  0.591191  0.610499  0.636766
# exp_4/exp_400  0.509895  0.517458  0.555068  0.590507  0.600724  0.630491
# exp_5/exp_500  0.503339  0.528359  0.538536  0.553821  0.573492  0.580209
# exp_6/exp_600  0.505028  0.517900  0.532904  0.550040  0.556879  0.561947
# exp_7/exp_700  0.501488  0.507200  0.521521  0.524457  0.540990  0.544409
# exp_8/exp_800  0.501971  0.505511  0.509694  0.519268  0.525302  0.531335
# exp_9/exp_900  0.505833  0.508246  0.505430  0.509574  0.518142  0.525623
#
#                 Bin 70%   Bin 80%   Bin 90%  Bin 100%
# Experiment
# exp_1/exp_100  0.663878  0.683146  0.732663  0.784717
# exp_4/exp_400  0.629726  0.651086  0.669912  0.712074
# exp_5/exp_500  0.595414  0.608286  0.626911  0.658604
# exp_6/exp_600  0.568986  0.579767  0.584071  0.608865
# ...
